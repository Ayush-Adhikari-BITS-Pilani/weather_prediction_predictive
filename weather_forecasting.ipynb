# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-257d506b-4db3-4318-b0cd-a30afbc73302" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-257d506b-4db3-4318-b0cd-a30afbc73302">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['POWER_Point_Daily_19810201_20240220_028d6835N_077d2200E_LST (1).csv']), sep =',', header =15)
print(df)
# Out:
#        YEAR  MO  DY     T2M    QV2M    RH2M  PRECTOTCORR  T2M_MAX  T2M_MIN  \
# 0      1981   2   1   13.92    4.88   52.44         2.17    22.25     8.29
# 1      1981   2   2   12.54    4.03   47.94         0.00    20.87     5.07
# 2      1981   2   3   14.46    4.21   44.81         0.15    23.46     7.30
# 3      1981   2   4   16.14    4.46   43.88         0.90    26.19     8.28
# 4      1981   2   5   16.76    5.13   45.94         1.81    26.40    11.27
# ...     ...  ..  ..     ...     ...     ...          ...      ...      ...
# 15720  2024   2  16   16.26    3.91   37.00         0.00    27.06     7.92
# 15721  2024   2  17   17.02    4.09   36.06         0.00    26.96     8.12
# 15722  2024   2  18   19.58    4.88   35.50         0.00    29.01    12.12
# 15723  2024   2  19   19.87    6.16   44.56         0.05    29.13    11.55
# 15724  2024   2  20 -999.00 -999.00 -999.00      -999.00  -999.00  -999.00
#
#            PS
# 0       99.37
# 1       99.46
# 2       99.35
# ...

# %%
data = pd.DataFrame(df)
data
# Out:
#        YEAR  MO  DY     T2M    QV2M    RH2M  PRECTOTCORR  T2M_MAX  T2M_MIN  \
# 0      1981   2   1   13.92    4.88   52.44         2.17    22.25     8.29
# 1      1981   2   2   12.54    4.03   47.94         0.00    20.87     5.07
# 2      1981   2   3   14.46    4.21   44.81         0.15    23.46     7.30
# 3      1981   2   4   16.14    4.46   43.88         0.90    26.19     8.28
# 4      1981   2   5   16.76    5.13   45.94         1.81    26.40    11.27
# ...     ...  ..  ..     ...     ...     ...          ...      ...      ...
# 15720  2024   2  16   16.26    3.91   37.00         0.00    27.06     7.92
# 15721  2024   2  17   17.02    4.09   36.06         0.00    26.96     8.12
# 15722  2024   2  18   19.58    4.88   35.50         0.00    29.01    12.12
# 15723  2024   2  19   19.87    6.16   44.56         0.05    29.13    11.55
# 15724  2024   2  20 -999.00 -999.00 -999.00      -999.00  -999.00  -999.00
#
#            PS
# 0       99.37
# 1       99.46
# 2       99.35
# ...

# %%
data.describe()
# Out:
#                YEAR            MO            DY           T2M          QV2M  \
# count  15725.000000  15725.000000  15725.000000  15725.000000  15725.000000
# mean    2002.112750      6.517393     15.722353     25.524400      9.324469
# std       12.429304      3.450328      8.798884     11.252052     10.097393
# min     1981.000000      1.000000      1.000000   -999.000000   -999.000000
# 25%     1991.000000      4.000000      8.000000     18.810000      4.460000
# 50%     2002.000000      7.000000     16.000000     26.830000      7.020000
# 75%     2013.000000     10.000000     23.000000     31.660000     14.530000
# max     2024.000000     12.000000     31.000000     41.810000     23.130000
#
#                RH2M   PRECTOTCORR       T2M_MAX       T2M_MIN           PS
# count  15725.000000  15725.000000  15725.000000  15725.000000  15725.00000
# mean      44.018422      1.971076     33.061976     18.951708     98.30944
# ...

# %%
data.isnull().sum()
# Out:
# YEAR           0
# MO             0
# DY             0
# T2M            0
# QV2M           0
# RH2M           0
# PRECTOTCORR    0
# T2M_MAX        0
# T2M_MIN        0
# PS             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15725 entries, 0 to 15724
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         15725 non-null  int64
#  1   MO           15725 non-null  int64
#  2   DY           15725 non-null  int64
#  3   T2M          15725 non-null  float64
#  4   QV2M         15725 non-null  float64
#  5   RH2M         15725 non-null  float64
#  6   PRECTOTCORR  15725 non-null  float64
#  7   T2M_MAX      15725 non-null  float64
#  8   T2M_MIN      15725 non-null  float64
#  9   PS           15725 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 1.2 MB
